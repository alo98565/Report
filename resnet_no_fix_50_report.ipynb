# %% [markdown]
# <div align="center">
#
# # National Tsing Hua University
#
# ### Fall 2023
#
# #### 11210IPT 553000
#
# #### Deep Learning in Biomedical Optical Imaging
#
# ## Report
# </div>

# %%
# Download train and val dataset
# !wget -q -O report_train.npy "https://www.dropbox.com/scl/fi/30dlbblp7wytcvoy05col/report_train.npy?rlkey=jx100qoz5n1d654v2mi32i9aj&dl=1"
# !wget -q -O report_val.npy "https://www.dropbox.com/scl/fi/oo6g1yqhbjm22wffeddgv/report_val.npy?rlkey=9rqe0rucjhrbzv3x7xbs5047z&dl=1"

# %% [markdown]
# ## A. Data Loading and Preprocessing

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset, random_split
import numpy as np

# Load Dataset
x_train = np.transpose(np.load('report_train.npy'), (0, 3, 1, 2))
x_val = np.transpose(np.load('report_val.npy'), (0, 3, 1, 2))

print(f'Shape of x_train: {x_train.shape}')
print(f'Shape of x_val: {x_val.shape}')

num_classes = 6

# Create labels
y_train = np.concatenate([np.full(425, i) for i in range(num_classes)])
y_val = np.concatenate([np.full(100, i) for i in range(num_classes)])

# Convert to PyTorch tensors
x_train = torch.from_numpy(x_train).float()
y_train = torch.from_numpy(y_train).long()

x_val = torch.from_numpy(x_val).float()
y_val = torch.from_numpy(y_val).long()
# Out:
# Shape of x_train: (2550, 3, 150, 150)
# Shape of x_val: (600, 3, 150, 150)

# %%
batch_size = 32

# Create datasets
train_dataset = TensorDataset(x_train, y_train)
val_dataset = TensorDataset(x_val, y_val)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

print(f'Number of samples in train and validation are {len(train_loader.dataset)} and {len(val_loader.dataset)}.')
print(f'X_train: max value is {x_train.max().item()}, min value is {x_train.min().item()}, data type is {x_train.dtype}.')
# Out:
# Number of samples in train and validation are 2550 and 600.
# X_train: max value is 255.0, min value is 0.0, data type is torch.float32.

# %%
import matplotlib.pyplot as plt
import random

class_names = ['Tumor', 'Stroma', 'Complex', 'Lympho', 'Debris', 'Mucosa']

num_classes = 6
samples_per_class = 3

fig, axes = plt.subplots(samples_per_class, num_classes, figsize=(12, 6))

plt.subplots_adjust(left=0.05, right=0.95, bottom=0.05, top=0.95, wspace=0.1, hspace=0.1)

for class_idx in range(num_classes):
    indices_of_class = np.where(y_train == class_idx)[0]
    random_indices = random.sample(list(indices_of_class), samples_per_class)

    for i in range(samples_per_class):
        ax = axes[i, class_idx]
        img = x_train[random_indices[i]].numpy().transpose((1, 2, 0))
        img = img / img.max()
        ax.imshow(img)
        ax.axis('off')

        if i == 0:
            ax.set_title(f'{class_idx} {class_names[class_idx]}', pad=3)

plt.show()

# %% [markdown]
# ## B. Defining Neural Networks

# %%
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models

model = models.resnet50(weights='IMAGENET1K_V1')

# ConvNet as fixed feature extractor (freeze parameters)
# for param in model.parameters():
#     param.requires_grad = False

num_ftrs = model.fc.in_features


# Here the size of each output sample is set to 6.
# Alternatively, it can be generalized to ``nn.Linear(num_ftrs, len(class_names))``.
model.fc = nn.Linear(num_ftrs, 6)
model = model.cuda()
# print(model)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:01<00:00, 82.0MB/s]

# %% [markdown]
# ## C. Training the Neural Network

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR, StepLR
from tqdm.auto import tqdm

train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

epochs =30

# Change you model here
# model = ConvGAP()
# print(model)
# model = model.cuda()

best_val_loss = float('inf')
best_val_acc = -1

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
lr_scheduler = CosineAnnealingLR(optimizer, T_max=len(train_loader)*epochs, eta_min=0)

for epoch in tqdm(range(epochs)):
    # Training
    model.train()
    total_loss = 0.0
    train_correct = 0
    total_train_samples = 0

    for images, labels in train_loader:
        images = images.cuda()
        images = images / 255.
        labels = labels.cuda()
        optimizer.zero_grad()
        outputs = model(images)

        labels = labels.long()

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

        train_predicted = outputs.argmax(-1)
        train_correct += (train_predicted.float() == labels).sum().item()
        total_train_samples += labels.size(0)

    avg_train_loss = total_loss / len(train_loader)
    train_accuracy = 100. * train_correct / total_train_samples

    # Validation
    model.eval()
    total_val_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in val_loader:
            images = images.cuda()
            images = images / 255.
            labels = labels.cuda()
            outputs = model(images)

            labels = labels.long()

            loss = criterion(outputs, labels)
            total_val_loss += loss.item()

            predicted = outputs.argmax(-1)
            correct += (predicted.float() == labels).sum().item()
            total += labels.size(0)

    avg_val_loss = total_val_loss / len(val_loader)
    val_accuracy = 100. * correct / total

    # Learning rate update
    lr_scheduler.step()

    # Checkpoint
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss

    if val_accuracy > best_val_acc:
        best_val_acc = val_accuracy
        torch.save(model.state_dict(), 'model_classification.pth')

    print(f'Epoch {epoch+1}/{epochs}, Train loss: {avg_train_loss:.4f}, Train acc: {train_accuracy:.2f}%, Val loss: {avg_val_loss:.4f}, Val acc: {val_accuracy:.2f}%, Best Val loss: {best_val_loss:.4f} Best Val acc: {best_val_acc:.2f}%')

    # Store performance
    train_losses.append(avg_train_loss)
    train_accuracies.append(train_accuracy)
    val_losses.append(avg_val_loss)
    val_accuracies.append(val_accuracy)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch 1/30, Train loss: 0.7089, Train acc: 75.37%, Val loss: 0.6998, Val acc: 75.17%, Best Val loss: 0.6998 Best Val acc: 75.17%
# Epoch 2/30, Train loss: 0.4428, Train acc: 84.59%, Val loss: 0.6475, Val acc: 75.17%, Best Val loss: 0.6475 Best Val acc: 75.17%
# Epoch 3/30, Train loss: 0.3342, Train acc: 88.31%, Val loss: 0.7417, Val acc: 75.17%, Best Val loss: 0.6475 Best Val acc: 75.17%
# Epoch 4/30, Train loss: 0.3601, Train acc: 87.22%, Val loss: 0.6968, Val acc: 75.17%, Best Val loss: 0.6475 Best Val acc: 75.17%
# Epoch 5/30, Train loss: 0.3001, Train acc: 90.35%, Val loss: 0.6311, Val acc: 80.17%, Best Val loss: 0.6311 Best Val acc: 80.17%
# Epoch 6/30, Train loss: 0.2836, Train acc: 90.39%, Val loss: 0.3244, Val acc: 87.33%, Best Val loss: 0.3244 Best Val acc: 87.33%
# Epoch 7/30, Train loss: 0.1933, Train acc: 93.22%, Val loss: 0.3629, Val acc: 88.17%, Best Val loss: 0.3244 Best Val acc: 88.17%
# Epoch 8/30, Train loss: 0.2037, Train acc: 92.90%, Val loss: 1.4747, Val acc: 71.50%, Best Val loss: 0.3244 Best Val acc: 88.17%
# Epoch 9/30, Train loss: 0.1645, Train acc: 94.78%, Val loss: 0.8148, Val acc: 75.67%, Best Val loss: 0.3244 Best Val acc: 88.17%
# Epoch 10/30, Train loss: 0.1719, Train acc: 94.51%, Val loss: 0.5232, Val acc: 86.00%, Best Val loss: 0.3244 Best Val acc: 88.17%
# Epoch 11/30, Train loss: 0.1226, Train acc: 95.69%, Val loss: 0.4494, Val acc: 84.67%, Best Val loss: 0.3244 Best Val acc: 88.17%
# Epoch 12/30, Train loss: 0.0715, Train acc: 97.41%, Val loss: 0.7054, Val acc: 83.17%, Best Val loss: 0.3244 Best Val acc: 88.17%
# Epoch 13/30, Train loss: 0.0893, Train acc: 96.98%, Val loss: 0.7792, Val acc: 80.17%, Best Val loss: 0.3244 Best Val acc: 88.17%
# Epoch 14/30, Train loss: 0.1193, Train acc: 95.73%, Val loss: 2.4281, Val acc: 62.00%, Best Val loss: 0.3244 Best Val acc: 88.17%
# Epoch 15/30, Train loss: 0.0878, Train acc: 97.49%, Val loss: 0.6735, Val acc: 83.50%, Best Val loss: 0.3244 Best Val acc: 88.17%
# Epoch 16/30, Train loss: 0.0858, Train acc: 96.86%, Val loss: 0.5078, Val acc: 85.17%, Best Val loss: 0.3244 Best Val acc: 88.17%
# Epoch 17/30, Train loss: 0.0464, Train acc: 98.63%, Val loss: 0.4396, Val acc: 87.83%, Best Val loss: 0.3244 Best Val acc: 88.17%
# Epoch 18/30, Train loss: 0.0542, Train acc: 97.88%, Val loss: 1.8697, Val acc: 76.83%, Best Val loss: 0.3244 Best Val acc: 88.17%
# Epoch 19/30, Train loss: 0.1595, Train acc: 95.33%, Val loss: 0.9669, Val acc: 77.33%, Best Val loss: 0.3244 Best Val acc: 88.17%
# Epoch 20/30, Train loss: 0.0793, Train acc: 97.22%, Val loss: 0.8269, Val acc: 81.50%, Best Val loss: 0.3244 Best Val acc: 88.17%
# Epoch 21/30, Train loss: 0.0915, Train acc: 97.06%, Val loss: 0.8928, Val acc: 80.17%, Best Val loss: 0.3244 Best Val acc: 88.17%
# Epoch 22/30, Train loss: 0.0768, Train acc: 97.37%, Val loss: 0.7088, Val acc: 81.33%, Best Val loss: 0.3244 Best Val acc: 88.17%
# Epoch 23/30, Train loss: 0.0275, Train acc: 99.29%, Val loss: 0.7911, Val acc: 82.67%, Best Val loss: 0.3244 Best Val acc: 88.17%
# Epoch 24/30, Train loss: 0.0536, Train acc: 98.71%, Val loss: 0.5029, Val acc: 84.67%, Best Val loss: 0.3244 Best Val acc: 88.17%
# Epoch 25/30, Train loss: 0.0391, Train acc: 98.86%, Val loss: 0.5483, Val acc: 86.17%, Best Val loss: 0.3244 Best Val acc: 88.17%
# Epoch 26/30, Train loss: 0.0432, Train acc: 98.67%, Val loss: 0.4947, Val acc: 87.17%, Best Val loss: 0.3244 Best Val acc: 88.17%
# Epoch 27/30, Train loss: 0.0593, Train acc: 98.08%, Val loss: 0.4737, Val acc: 86.83%, Best Val loss: 0.3244 Best Val acc: 88.17%
# Epoch 28/30, Train loss: 0.0278, Train acc: 99.29%, Val loss: 0.4120, Val acc: 89.50%, Best Val loss: 0.3244 Best Val acc: 89.50%
# Epoch 29/30, Train loss: 0.0220, Train acc: 99.45%, Val loss: 0.5019, Val acc: 86.67%, Best Val loss: 0.3244 Best Val acc: 89.50%
# Epoch 30/30, Train loss: 0.0299, Train acc: 98.82%, Val loss: 0.7031, Val acc: 82.67%, Best Val loss: 0.3244 Best Val acc: 89.50%

# %% [markdown]
# ### Visualizing model performance

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 5))

# Plotting training and validation accuracy
ax[0].plot(train_accuracies)
ax[0].plot(val_accuracies)
ax[0].set_title('ResNet50 no fixed Model Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(['Train', 'Val'])

# Plotting training and validation loss
ax[1].plot(train_losses)
ax[1].plot(val_losses)
ax[1].set_title('ResNet50 no fixed Model Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(['Train', 'Val'])

plt.show()

# %% [markdown]
# ## D. Evaluating Your Trained Model

# %% [markdown]
# ### Process Test Dataset

# %%
# Download test dataset,
# !wget -q -O report_test.npy "https://www.dropbox.com/scl/fi/ufcagx2cvjmervgqrgwrt/report_test.npy?rlkey=fijueom5x54628ivpzeki2bt0&dl=1"

# %%
x_test = np.transpose(np.load('report_test.npy'), (0, 3, 1, 2))
print(f'Shape of x_test: {x_test.shape}')

y_test = np.concatenate([np.full(100, i) for i in range(num_classes)])

x_test = torch.from_numpy(x_test).float()
y_test = torch.from_numpy(y_test).long()

print(f'x_test: max value is {x_test.max().item()}, min value is {x_test.min().item()}, data type is {x_test.dtype}.')

batch_size = 32

# Combine the images and labels into a dataset
test_dataset = TensorDataset(x_test, y_test)

# Create a dataloader to load data in batches. Set batch size to 32.
test_loader = DataLoader(test_dataset, batch_size, shuffle=False)
# Out:
# Shape of x_test: (600, 3, 150, 150)
# x_test: max value is 255.0, min value is 0.0, data type is torch.float32.

# %% [markdown]
# ### Load Trained Model and Evaluate

# %%
# Load the trained weights
model.load_state_dict(torch.load('model_classification.pth'))

# Set the model to evaluation mode
model.eval()

test_correct = 0
test_total = 0

with torch.no_grad():
    for images, labels in test_loader:

        images = images.cuda()
        images = images / 255.

        labels = labels.cuda()
        labels = labels.long()

        outputs = model(images)

        predicted = outputs.argmax(-1)
        test_correct += (predicted.float() == labels).sum().item()
        test_total += labels.size(0)

print(f'Test accuracy is {100. * test_correct / test_total}%')
# Out:
# Test accuracy is 90.33333333333333%
